# %%
from load import open_pickle

tuple(str(pickle_path(f"S{i}",f"S{i}.pkl"))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from learn import Learn
# Out:
# Exception in thread Thread-5 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-6 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
# Exception in thread Thread-7 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 15 were given
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#     Exception in thread Thread-8 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 15 were given
# self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 15 were given
# Exception in thread Thread-9 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-10 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-11 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
# Exception in thread Thread-12 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 15 were given
# Exception in thread Thread-13 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
# Exception in thread Thread-14 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 15 were given
# Exception in thread Thread-15 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 15 were given
# Exception in thread Thread-16 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 15 were given
#     Exception in thread Thread-17 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
# self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 17 were given
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 15 were given
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 17 were given
# Exception in thread Thread-18 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-19 (open_pickle):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 17 were given
# self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 17 were given
#     self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 17 were given
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 17 were given
#     self._target(*self._args, **self._kwargs)
# TypeError: open_pickle() takes 1 positional argument but 17 were given
# load: S2 S3 S4 S5 S6 S7 S8 S9 S10 S11 S13 S14 S15 S16 S17 Finish build DataFrame

# %%
models = [DecisionTreeClassifier(random_state=0),
          RandomForestClassifier(),
          AdaBoostClassifier(n_estimators=100,random_state=0),
          LinearDiscriminantAnalysis(),
          KNeighborsClassifier(n_neighbors=3)]
for model in models:
    class_name = model.__class__.__name__
    print(f"---------------{class_name}---------------")
    learn = Learn(model)
    print(learn.test())
    print('-'*(30+len(class_name)))
# Out:
# ---------------DecisionTreeClassifier---------------
#               precision    recall  f1-score   support
#
#            1       0.83      0.77      0.80        13
#            2       0.75      0.82      0.78        11
#
#     accuracy                           0.79        24
#    macro avg       0.79      0.79      0.79        24
# weighted avg       0.80      0.79      0.79        24
#
# ----------------------------------------------------
# ---------------RandomForestClassifier---------------
#               precision    recall  f1-score   support
#
#            1       0.85      0.85      0.85        13
#            2       0.82      0.82      0.82        11
#
#     accuracy                           0.83        24
#    macro avg       0.83      0.83      0.83        24
# weighted avg       0.83      0.83      0.83        24
#
# ----------------------------------------------------
# ---------------AdaBoostClassifier---------------
#               precision    recall  f1-score   support
#
#            1       0.79      0.85      0.81        13
#            2       0.80      0.73      0.76        11
#
#     accuracy                           0.79        24
#    macro avg       0.79      0.79      0.79        24
# weighted avg       0.79      0.79      0.79        24
#
# ------------------------------------------------
# ---------------LinearDiscriminantAnalysis---------------
#               precision    recall  f1-score   support
#
#            1       0.89      0.62      0.73        13
#            2       0.67      0.91      0.77        11
#
#     accuracy                           0.75        24
#    macro avg       0.78      0.76      0.75        24
# weighted avg       0.79      0.75      0.75        24
#
# --------------------------------------------------------
# ---------------KNeighborsClassifier---------------
#               precision    recall  f1-score   support
#
#            1       1.00      0.54      0.70        13
#            2       0.65      1.00      0.79        11
#
#     accuracy                           0.75        24
#    macro avg       0.82      0.77      0.74        24
# weighted avg       0.84      0.75      0.74        24
#
# --------------------------------------------------
