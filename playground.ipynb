# %%
import load
import matplotlib.pyplot as plt
import feature as feat
from collections import Counter

# %%
wesad = load.WESAD(max_workers = 3)
# Out:
# Using ready-made DataFrame

# %%
Counter(wesad._df['label'])
# Out:
# Counter({0: 4711700,
#          1: 2478001,
#          5: 105000,
#          3: 785400,
#          7: 88900,
#          4: 1667400,
#          2: 1448300,
#          6: 101499})

# %%
res = wesad.separate_and_feature_extract(sample_n=100000)

# %%
res
# Out:
#      label subject  std_ACC_0  mean_ACC_0  std_ACC_1  mean_ACC_1  std_ACC_2  \
# 0        1     S10   0.021321    0.889132   0.063031    0.020803   0.202298
# 1        1     S10   0.021365    0.888996   0.062894    0.020948   0.202869
# 2        1     S10   0.021311    0.889068   0.062566    0.021411   0.202364
# 3        1     S10   0.021223    0.889043   0.062864    0.021442   0.202268
# 4        1     S10   0.021209    0.888992   0.062915    0.021620   0.202176
# ..     ...     ...        ...         ...        ...         ...        ...
# 793      2     S13   0.026360    0.873005   0.069523   -0.040778   0.093739
# 794      2     S13   0.026318    0.873108   0.069591   -0.040639   0.093922
# 795      2     S13   0.026468    0.873337   0.069718   -0.040614   0.092858
# 796      2     S13   0.027051    0.873381   0.069212   -0.040438   0.093796
# 797      2     S13   0.026482    0.873522   0.069385   -0.041357   0.093838
#
#      mean_ACC_2  ECG_ULF  ECG_LF  ECG_HF   ECG_UHF   std_EMG  mean_EMG  \
# 0     -0.042235      0.0     0.0     0.0  0.018482  0.009670 -0.002457
# 1     -0.043282      0.0     0.0     0.0  0.026869  0.009705 -0.002535
# 2     -0.043707      0.0     0.0     0.0  0.023192  0.009730 -0.002485
# 3     -0.043754      0.0     0.0     0.0  0.007285  0.009772 -0.002481
# 4     -0.044093      0.0     0.0     0.0  0.005205  0.009815 -0.002543
# ..          ...      ...     ...     ...       ...       ...       ...
# 793   -0.280442      0.0     0.0     0.0  0.001308  0.011959 -0.003521
# 794   -0.279905      0.0     0.0     0.0  0.001931  0.012009 -0.003475
# 795   -0.280413      0.0     0.0     0.0  0.003175  0.011988 -0.003484
# 796   -0.279975      0.0     0.0     0.0  0.007790  0.012042 -0.003408
# 797   -0.280050      0.0     0.0     0.0  0.004784  0.012143 -0.003537
#
#       std_EDA  mean_EDA  std_Resp  mean_Resp  std_Temp  mean_Temp
# 0    0.030827  0.787163  2.637272   0.039095  0.118833  34.289314
# 1    0.030920  0.786871  2.623433   0.027733  0.119630  34.288513
# 2    0.030981  0.786747  2.652301   0.033623  0.120497  34.287807
# 3    0.031086  0.786852  2.630625   0.040523  0.121389  34.287506
# 4    0.030805  0.787000  2.618465   0.042632  0.119879  34.288109
# ..        ...       ...       ...        ...       ...        ...
# 793  0.800626  4.607523  7.286779   0.044710  0.184961  34.346066
# 794  0.798123  4.604554  7.243647   0.044844  0.184946  34.345970
# 795  0.796219  4.606935  7.218296   0.009921  0.184644  34.346828
# 796  0.794552  4.605069  7.215937   0.016689  0.184336  34.346497
# 797  0.793834  4.607337  7.256841  -0.003287  0.183562  34.345608
#
# [798 rows x 20 columns]

# %%
res['ECG_LF'][0]
# Out:
# 0.0

# %%
import pandas as pd

# Sample data
data = {'A': [1, 1, 2, 2, 2, 3, 3],
        'B': ['X', 'X', 'Y', 'Y', 'Z', 'Z', 'Z']}
df = pd.DataFrame(data)

# Detect changes in 'A' or 'B'
df['group'] = (df['A'] != df['A'].shift()) | (df['B'] != df['B'].shift())
df['group'] = df['group'].cumsum()  # Create unique group numbers

# Print groups
for _, group in df.groupby('group'):
    print(group, '\n')
    print(_)
# Out:
#    A  B  group
# 0  1  X      1
# 1  1  X      1
#
# 1
#    A  B  group
# 2  2  Y      2
# 3  2  Y      2
#
# 2
#    A  B  group
# 4  2  Z      3
#
# 3
#    A  B  group
# 5  3  Z      4
# 6  3  Z      4
#
# 4

# %%
[g for _,g in df.groupby('group')]
# Out:
# [   A  B  group
#  0  1  X      1
#  1  1  X      1,
#     A  B  group
#  2  2  Y      2
#  3  2  Y      2,
#     A  B  group
#  4  2  Z      3,
#     A  B  group
#  5  3  Z      4
#  6  3  Z      4]
