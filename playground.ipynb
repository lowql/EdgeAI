# %%
import load
import matplotlib.pyplot as plt
import feature as feat

# %%
wesad = load.WESAD(max_workers = 3, subject_count = 3)
# Out:
# Finished building DataFrame

# %%
# rolling_data = wesad.rolling_window(ecg_signal, window_size=7000)
# print(len(rolling_data))

# %%
res = wesad.feature_extraction()

# %%
res
# Out:
#      label  std_ACC_0  mean_ACC_0  std_ACC_1  mean_ACC_1  std_ACC_2  \
# 0        1   0.021420    0.888941   0.063171    0.020209   0.203178
# 1        1   0.021296    0.889040   0.063295    0.020606   0.202416
# 2        1   0.021233    0.889102   0.063245    0.020834   0.202319
# 3        1   0.021145    0.889135   0.063540    0.020151   0.202644
# 4        1   0.021292    0.889174   0.063832    0.019536   0.202639
# ..     ...        ...         ...        ...         ...        ...
# 105      2   0.029302    0.873098   0.068947   -0.043725   0.094417
# 106      2   0.029301    0.873199   0.068595   -0.043655   0.094038
# 107      2   0.029403    0.873059   0.068814   -0.043065   0.094453
# 108      2   0.029268    0.873057   0.068671   -0.042460   0.094823
# 109      2   0.028913    0.873290   0.068638   -0.042033   0.095540
#
#      mean_ACC_2  ECG_ULF  ECG_LF    ECG_HF   ECG_UHF   std_EMG  mean_EMG  \
# 0     -0.043104      0.0     0.0  0.000000  0.001014  0.009886 -0.002596
# 1     -0.042446      0.0     0.0  0.000000  0.001467  0.009907 -0.002563
# 2     -0.043107      0.0     0.0  0.000000  0.001693  0.009827 -0.002618
# 3     -0.041472      0.0     0.0  0.001271  0.001342  0.009805 -0.002587
# 4     -0.040146      0.0     0.0  0.000000  0.001524  0.009881 -0.002575
# ..          ...      ...     ...       ...       ...       ...       ...
# 105   -0.281073      0.0     0.0  0.000000  0.002308  0.011897 -0.003207
# 106   -0.281241      0.0     0.0  0.000000  0.002043  0.011936 -0.003195
# 107   -0.281048      0.0     0.0  0.000000  0.001007  0.011964 -0.003171
# 108   -0.281098      0.0     0.0  0.000000  0.001735  0.011977 -0.003262
# 109   -0.280480      0.0     0.0  0.000000  0.001700  0.011944 -0.003321
#
#       std_EDA  mean_EDA  std_Resp  mean_Resp  std_Temp  mean_Temp
# 0    0.030667  0.787743  2.656631   0.023853  0.119747  34.290791
# 1    0.030666  0.787818  2.676842   0.033273  0.120309  34.290325
# 2    0.030501  0.787769  2.676756   0.043886  0.119752  34.290871
# 3    0.030366  0.787942  2.668311   0.071459  0.119849  34.290909
# 4    0.030244  0.788086  2.675568   0.068011  0.119498  34.292042
# ..        ...       ...       ...        ...       ...        ...
# 105  0.791249  4.609848  7.519740   0.146955  0.181986  34.347443
# 106  0.790764  4.599867  7.514716   0.195537  0.182469  34.344788
# 107  0.789451  4.598134  7.505791   0.144291  0.182098  34.344482
# 108  0.792893  4.590967  7.447783   0.100183  0.183010  34.343708
# 109  0.788147  4.582702  7.389572   0.068999  0.182904  34.342354
#
# [110 rows x 19 columns]

# %%
res['ECG_LF'][0]
# Out:
# 0.0

# %%
time_signal = rolling_data[0]
decorator = feat.SignalDecorator(time_signal)
decorator.add_processor(feat.ButterBandpass(), lowcut=5, highcut=30, fs=70)
decorator.add_processor(feat.FFTProcessor())
processed_signal, results = decorator.apply()
# 繪圖
visualizer = feat.SignalVisualizer(time_signal, time_step=1/len(time_signal))
visualizer.plot(processed_signal, results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 time_signal = rolling_data[0]
#       2 decorator = feat.SignalDecorator(time_signal)
#       3 decorator.add_processor(feat.ButterBandpass(), lowcut=5, highcut=30, fs=70)
#
# NameError: name 'rolling_data' is not defined

# %%
import pandas as pd
import numpy as np

# Sample DataFrame
df = pd.DataFrame({
    "A": [1, 2, 3],
    "B": [4, 5, 6]
})

# New column values as an array
new_column_values = np.array([10, 20, 30])  # Can also be a list

# Add new column
df["C"] = new_column_values

print(df)
# Out:
#    A  B   C
# 0  1  4  10
# 1  2  5  20
# 2  3  6  30

# %%
import pandas as pd

data = {'values': [10, 20, 30, 40, 50, 60]}
df = pd.DataFrame(data)

roll_obj = df['values'].rolling(window=3, step=1, min_periods=3)
print(df)
# Out:
#    values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50
# 5      60

# %%
for x in roll_obj:
    print(x, type(x))
# Out:
# 0    10
# Name: values, dtype: int64 <class 'pandas.core.series.Series'>
# 0    10
# 1    20
# Name: values, dtype: int64 <class 'pandas.core.series.Series'>
# 0    10
# 1    20
# 2    30
# Name: values, dtype: int64 <class 'pandas.core.series.Series'>
# 1    20
# 2    30
# 3    40
# Name: values, dtype: int64 <class 'pandas.core.series.Series'>
# 2    30
# 3    40
# 4    50
# Name: values, dtype: int64 <class 'pandas.core.series.Series'>
# 3    40
# 4    50
# 5    60
# Name: values, dtype: int64 <class 'pandas.core.series.Series'>
