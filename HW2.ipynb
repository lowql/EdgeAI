# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from learn import Learn,wesad
import pandas as pd
# Out:
# Finished building DataFrame
# before sample: 193039030

# %% [markdown]
# ### mutiT_feature_extraction 內部程式講解

# %%
cols = ['label', 'subject', 'ACC_0', 'ACC_1', 'ACC_2', 'ECG', 'EMG', 'EDA', 'Resp', 'Temp']
sample_n = 7000
signal = wesad.group(sample_n=sample_n)
# Out:
# before sample: 193039030

# %%
subjects_len = len(wesad._subjects)

# %%
print(subjects_len*sample_n*2)
print(signal.shape[0])
# Out:
# 210000
# 210000

# %%
rolling_windows = {key: wesad.rolling_window(signal[key],window_size=7000) for key in cols}

# %%
df = pd.DataFrame(rolling_windows)
df.shape[0]
# Out:
# 203001

# %%
import feature as feat
rolling_windows['ECG'][0]
# Out:
# [-0.12945556640625,
#  -0.0288848876953125,
#  0.1297760009765625,
#  0.0687103271484375,
#  -0.0465545654296875,
#  0.0373992919921875,
#  0.0433502197265625,
#  0.07562255859375,
#  0.1243743896484375,
#  -0.0410614013671875,
#  0.0628509521484375,
#  0.1204376220703125,
#  0.0240325927734375,
#  0.8396759033203125,
#  0.0103912353515625,
#  0.04888916015625,
#  0.0953521728515625,
#  0.0798797607421875,
#  0.05804443359375,
#  0.5006561279296875,
#  0.1101837158203125,
#  -0.024993896484375,
#  0.1613616943359375,
#  0.1229095458984375,
#  -0.1084442138671875,
#  0.0269622802734375,
#  -0.0374908447265625,
#  0.1570587158203125,
#  0.0284271240234375,
#  0.04486083984375,
#  0.0342864990234375,
#  -0.0102081298828125,
#  -0.0044403076171875,
#  0.1257476806640625,
#  -0.2420196533203125,
#  -0.2077789306640625,
#  -0.1307373046875,
#  -0.0030670166015625,
#  0.0439910888671875,
#  0.1928558349609375,
#  -0.1589813232421875,
#  -0.0733795166015625,
#  0.0964508056640625,
# ...

# %%
# for i in range(df.shape[0]):
#     subject = df.loc[0,['subject']]
#     print(subject)

# %%
# df = pd.DataFrame(rolling_windows)
# df

# %% [markdown]
# # 特徵提取

# %%
df = wesad.mutiT_feature_extraction()
# Out:
# before sample: 193039030
# signal length: 413001/413001
# multi thread use 1 works
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = wesad.mutiT_feature_extraction()
#
# File d:\_study\DataScience\EdgeAI\load.py:131, in WESAD.mutiT_feature_extraction(self, sample_n, window_size, cols, limit, work_n)
#     129 print(f"multi thread use {work_n} works")
#     130 with ThreadPoolExecutor(max_workers=work_n) as exec:
# --> 131     features = list(exec.map(process_window_func,range(signal_length)))
#     132 feat_df = pd.DataFrame(features)
#     133 return feat_df
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\concurrent\futures\_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
# ...

# %%
df
# Out:
#       label subject  std_ACC_0  mean_ACC_0  std_ACC_1  mean_ACC_1  std_ACC_2  \
# 0         1     S13   0.087657    0.816735   0.102342    0.010026   0.279414
# 1         1     S13   0.087665    0.816666   0.102342    0.010030   0.279399
# 2         1     S13   0.087692    0.816618   0.102315    0.009991   0.279458
# 3         1     S13   0.087717    0.816546   0.102317    0.009996   0.279523
# 4         1     S13   0.087713    0.816485   0.102317    0.009996   0.279553
# ...     ...     ...        ...         ...        ...         ...        ...
# 4996      2     S14   0.063068    0.830540   0.064272    0.012610   0.148192
# 4997      2     S14   0.063081    0.830508   0.064263    0.012652   0.148216
# 4998      2     S14   0.063080    0.830468   0.064267    0.012685   0.148208
# 4999      2     S14   0.063075    0.830459   0.064180    0.012746   0.148201
# 5000      2     S14   0.063116    0.830406   0.064174    0.012788   0.148241
#
# ...

# %%
from learn import Learn,LOSOEvaluate
learn = Learn(DecisionTreeClassifier(random_state=0))
loso = LOSOEvaluate(learn)
loso.test()
# Out:
# shape of [subject,feature,labels] ((20,), (20, 8), (20,))
# model accuracy:  0.9500
#               precision    recall  f1-score   support
#
#            1     1.0000    0.9000    0.9474        10
#            2     0.9091    1.0000    0.9524        10
#
#     accuracy                         0.9500        20
#    macro avg     0.9545    0.9500    0.9499        20
# weighted avg     0.9545    0.9500    0.9499        20
